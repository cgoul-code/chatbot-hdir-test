# %%
import os, getpass

# LLM og verktøy
from llama_index.llms.azure_openai import AzureOpenAI
from llama_index.agent.openai import OpenAIAgent
from llama_index.core.tools import FunctionTool
from llama_index.core.llms import ChatMessage, MessageRole
from llama_index.core import ChatPromptTemplate
from llama_index.core.llms import ChatMessage
from llama_index.core import (get_response_synthesizer)
from llama_index.core import VectorStoreIndex
from llama_index.core.node_parser import SentenceSplitter
from llama_index.core import (VectorStoreIndex, StorageContext,  load_index_from_storage)

# Import av embedding-moduler
from llama_index.embeddings.azure_openai import AzureOpenAIEmbedding
from llama_index.embeddings.openai import OpenAIEmbeddingModelType

# Indeksverktøy
LLMGPT4omini = AzureOpenAI(
    model=os.getenv('AZURE_OPENAI_MODEL_GPT4omini'),
    deployment_name=os.getenv('AZURE_OPENAI_DEPLOYMENT_NAME_GPT4omini'),
    azure_deployment=os.getenv('AZURE_OPENAI_DEPLOYMENT_NAME_GPT4omini'),
    api_key=os.getenv('AZURE_OPENAI_API_KEY_GPT4omini'),
    azure_endpoint=os.getenv('AZURE_OPENAI_AZURE_ENDPOINT_GPT4omini'),
    api_version=os.getenv('AZURE_OPENAI_API_VERSJON_GPT4omini'),
    temperature=0.0,
    timeout= 120,
)

def read_index_from_storage(storage):
    storage_context = StorageContext.from_defaults(persist_dir=storage)
    return load_index_from_storage(storage_context)

# Sett Azure OpenAI-legitimasjon

llm = LLMGPT4omini

from typing_extensions import TypedDict

# Graph state
class State(TypedDict):
    topic: str
    joke: str
    story: str
    poem: str
    combined_output: str
   
def call_llm_1(state: State) :
    messages = [
        ChatMessage(role="system", content="You are a helpfull assistant" ),
        ChatMessage(role="user", content=f"Write a short joke about {state['topic']}")  ]
    response = llm.chat(messages)
    print(f'Response call_llm_1: {response.message.content}')

    return {'joke': response.message.content}

def call_llm_2(state: State) :
    messages = [
        ChatMessage(role="system", content="You are a helpfull assistant" ),
        ChatMessage(role="user", content=f"Write a story about: {state['topic']}")  ]
    response = llm.chat(messages)
    print(f'Response call_llm_2: {response.message.content}')

    return {'story': response.message.content}

def call_llm_3(state: State) :
    messages = [
        ChatMessage(role="system", content="You are a helpfull assistant" ),
        ChatMessage(role="user", content=f"Write a poem about: {state['topic']}")  ]
    response = llm.chat(messages)
    print(f'Response call_llm_3: {response.message.content}')

    return {'poem': response.message.content}


def aggregator(state: State):
    """Combine the joke and story into a single output"""

    combined = f"Here's a story, joke, and poem about {state['topic']}!\n\n"
    combined += f"STORY:\n{state['story']}\n\n"
    combined += f"JOKE:\n{state['joke']}\n\n"
    combined += f"POEM:\n{state['poem']}"
    return {"combined_output": combined}


    
from langgraph.graph import StateGraph, START, END
from IPython.display import Image, display

# Build workflow
parallel_builder = StateGraph(State)

# Add nodes
parallel_builder.add_node("call_llm_1", call_llm_1)
parallel_builder.add_node("call_llm_2", call_llm_2)
parallel_builder.add_node("call_llm_3", call_llm_3)
parallel_builder.add_node("aggregator", aggregator)

# Add edges to connect nodes
parallel_builder.add_edge(START, "call_llm_1")
parallel_builder.add_edge(START, "call_llm_2")
parallel_builder.add_edge(START, "call_llm_3")
parallel_builder.add_edge("call_llm_1", "aggregator")
parallel_builder.add_edge("call_llm_2", "aggregator")
parallel_builder.add_edge("call_llm_3", "aggregator")
parallel_builder.add_edge("aggregator", END)
parallel_workflow = parallel_builder.compile()

# Show workflow
#display(Image(parallel_workflow.get_graph().draw_mermaid_png()))

# Invoke
state = parallel_workflow.invoke({"topic": "cats"})
print(state["combined_output"])
# Out:
# Response call_llm_1: Why was the cat sitting on the computer?
#
# Because it wanted to keep an eye on the mouse!
# Response call_llm_3: In sunlit corners, soft and sleek,
# With whispered purrs, they softly speak,
# A flick of tail, a playful leap,
# In dreams of mice, they gently creep.
#
# With emerald eyes that gleam like stars,
# They roam the night, like tiny czars,
# On velvet paws, they tread so light,
# Guardians of shadows, cloaked in night.
#
# A stretch, a yawn, a graceful pose,
# In every nook, their charm bestows,
# They curl like whispers, warm and round,
# In every heart, their love is found.
#
# From playful pounces to quiet grace,
# Each little quirk, a sweet embrace,
# With every meow, a tale unfolds,
# Of ancient lore and secrets told.
#
# Oh, creatures of mystery, soft and wise,
# With a flick of whiskers and knowing sighs,
# In your presence, the world feels right,
# Oh, beloved cats, our pure delight.
# Response call_llm_2: **The Secret Society of Whiskers**
#
# In the quaint little town of Willowbrook, where the streets were lined with cobblestone and the air was filled with the scent of blooming flowers, there existed a secret society known only to a select few. This society was not made up of humans, but rather a group of clever and adventurous cats who roamed the town by night.
#
# The leader of this feline fraternity was a sleek black cat named Midnight. With her piercing green eyes and a coat that shimmered under the moonlight, she was both graceful and cunning. Midnight had a knack for solving mysteries, and her friends often turned to her for guidance. Her loyal companions included Whiskers, a fluffy orange tabby with a heart of gold; Luna, a mischievous Siamese with a penchant for trouble; and Oliver, a wise old tomcat who had seen it all.
#
# One crisp autumn evening, as the leaves danced in the cool breeze, the cats gathered at their secret meeting spot—a hidden alcove behind the old oak tree in the town square. The moon hung high in the sky, casting a silvery glow over their secret gathering.
#
# “Tonight, we have a mission,” Midnight announced, her voice low and serious. “The humans have reported strange noises coming from the abandoned house on Maple Street. They say it’s haunted, but I suspect there’s more to it than that.”
#
# Whiskers’ eyes widened with excitement. “Haunted? Do you think there are ghosts?”
#
# Luna flicked her tail, unimpressed. “Ghosts are just stories to scare humans. I bet it’s just a raccoon or something.”
#
# Oliver, who had been quietly observing, finally spoke up. “Whatever it is, we must investigate. The safety of our territory is at stake.”
#
# With a plan in place, the feline friends set off towards the abandoned house. The moonlight illuminated their path as they stealthily made their way through the shadows. The house loomed ahead, its windows dark and foreboding, but the cats were undeterred.
#
# As they approached, they heard the strange noises that had piqued their curiosity—a series of soft thumps and rustling sounds. Midnight led the way, her heart racing with anticipation. They slipped through a broken window, landing silently on the dusty floor inside.
#
# The interior of the house was dimly lit by the moonlight filtering through the cracks in the walls. Cobwebs hung from the corners, and the air was thick with the scent of mildew. The cats crept forward, their ears perked and tails twitching.
#
# Suddenly, a loud crash echoed from the back of the house, causing them to jump. Midnight motioned for silence, and they cautiously made their way toward the source of the noise. As they rounded a corner, they stumbled upon a sight that made their fur stand on end.
#
# In the center of the room was a group of raccoons, their little hands busy rummaging through a pile of old furniture and discarded items. They were the source of the strange noises, and they seemed completely unaware of the feline intruders.
#
# “Look at them!” Luna whispered, her eyes gleaming with mischief. “They’re just scavenging. We should scare them off!”
#
# Midnight shook her head. “No, wait. Let’s see what they’re up to first.”
#
# The cats watched as the raccoons uncovered a dusty old trunk. With a collective effort, they pried it open, revealing a treasure trove of forgotten trinkets—old toys, shiny buttons, and even a few pieces of jewelry that sparkled in the moonlight.
#
# Whiskers’ eyes widened in awe. “They’re hoarding all this stuff! We should take some for ourselves!”
#
# But Midnight had a different idea. “What if we help them? We could form an alliance. They could help us keep the town safe from other intruders.”
#
# The other cats exchanged glances, considering Midnight’s proposal. Finally, they nodded in agreement.
#
# With a deep breath, Midnight stepped forward, her voice steady. “Excuse me, raccoons! We mean you no harm. We’ve been watching you, and we’d like to propose a partnership.”
#
# The raccoons froze, their eyes wide with surprise. After a moment, the largest raccoon, who seemed to be the leader, stepped forward. “Partnership? What do you have in mind?”
#
# Midnight explained their plan: the cats would help the raccoons keep the town safe from any threats, and in return, the raccoons would share their scavenged treasures and help the cats with their own adventures.
#
# The raccoons considered the offer, and after a brief huddle, they agreed. From that night on, the cats and raccoons formed an unlikely alliance, patrolling the streets of Willowbrook together, sharing stories, and protecting their territory from any intruders.
#
# As the moon shone brightly over the town, Midnight, Whiskers, Luna, and Oliver returned to their secret meeting spot, their hearts filled with excitement for the adventures that lay ahead. They had not only solved the mystery of the abandoned house but had also forged a new friendship that would last for years to come.
#
# And so, the Secret Society of Whiskers continued to thrive, their bond growing stronger with each passing night, proving that even the most unlikely of allies could come together for a common cause. In Willowbrook, the cats and raccoons became legends, their tales whispered among the townsfolk, who could never quite explain the strange happenings that seemed to protect their little town.
# Here's a story, joke, and poem about cats!
#
# STORY:
# **The Secret Society of Whiskers**
#
# In the quaint little town of Willowbrook, where the streets were lined with cobblestone and the air was filled with the scent of blooming flowers, there existed a secret society known only to a select few. This society was not made up of humans, but rather a group of clever and adventurous cats who roamed the town by night.
#
# The leader of this feline fraternity was a sleek black cat named Midnight. With her piercing green eyes and a coat that shimmered under the moonlight, she was both graceful and cunning. Midnight had a knack for solving mysteries, and her friends often turned to her for guidance. Her loyal companions included Whiskers, a fluffy orange tabby with a heart of gold; Luna, a mischievous Siamese with a penchant for trouble; and Oliver, a wise old tomcat who had seen it all.
#
# One crisp autumn evening, as the leaves danced in the cool breeze, the cats gathered at their secret meeting spot—a hidden alcove behind the old oak tree in the town square. The moon hung high in the sky, casting a silvery glow over their secret gathering.
#
# “Tonight, we have a mission,” Midnight announced, her voice low and serious. “The humans have reported strange noises coming from the abandoned house on Maple Street. They say it’s haunted, but I suspect there’s more to it than that.”
#
# Whiskers’ eyes widened with excitement. “Haunted? Do you think there are ghosts?”
#
# Luna flicked her tail, unimpressed. “Ghosts are just stories to scare humans. I bet it’s just a raccoon or something.”
#
# Oliver, who had been quietly observing, finally spoke up. “Whatever it is, we must investigate. The safety of our territory is at stake.”
#
# With a plan in place, the feline friends set off towards the abandoned house. The moonlight illuminated their path as they stealthily made their way through the shadows. The house loomed ahead, its windows dark and foreboding, but the cats were undeterred.
#
# As they approached, they heard the strange noises that had piqued their curiosity—a series of soft thumps and rustling sounds. Midnight led the way, her heart racing with anticipation. They slipped through a broken window, landing silently on the dusty floor inside.
#
# The interior of the house was dimly lit by the moonlight filtering through the cracks in the walls. Cobwebs hung from the corners, and the air was thick with the scent of mildew. The cats crept forward, their ears perked and tails twitching.
#
# Suddenly, a loud crash echoed from the back of the house, causing them to jump. Midnight motioned for silence, and they cautiously made their way toward the source of the noise. As they rounded a corner, they stumbled upon a sight that made their fur stand on end.
#
# In the center of the room was a group of raccoons, their little hands busy rummaging through a pile of old furniture and discarded items. They were the source of the strange noises, and they seemed completely unaware of the feline intruders.
#
# “Look at them!” Luna whispered, her eyes gleaming with mischief. “They’re just scavenging. We should scare them off!”
#
# Midnight shook her head. “No, wait. Let’s see what they’re up to first.”
#
# The cats watched as the raccoons uncovered a dusty old trunk. With a collective effort, they pried it open, revealing a treasure trove of forgotten trinkets—old toys, shiny buttons, and even a few pieces of jewelry that sparkled in the moonlight.
#
# Whiskers’ eyes widened in awe. “They’re hoarding all this stuff! We should take some for ourselves!”
#
# But Midnight had a different idea. “What if we help them? We could form an alliance. They could help us keep the town safe from other intruders.”
#
# The other cats exchanged glances, considering Midnight’s proposal. Finally, they nodded in agreement.
#
# With a deep breath, Midnight stepped forward, her voice steady. “Excuse me, raccoons! We mean you no harm. We’ve been watching you, and we’d like to propose a partnership.”
#
# The raccoons froze, their eyes wide with surprise. After a moment, the largest raccoon, who seemed to be the leader, stepped forward. “Partnership? What do you have in mind?”
#
# Midnight explained their plan: the cats would help the raccoons keep the town safe from any threats, and in return, the raccoons would share their scavenged treasures and help the cats with their own adventures.
#
# The raccoons considered the offer, and after a brief huddle, they agreed. From that night on, the cats and raccoons formed an unlikely alliance, patrolling the streets of Willowbrook together, sharing stories, and protecting their territory from any intruders.
#
# As the moon shone brightly over the town, Midnight, Whiskers, Luna, and Oliver returned to their secret meeting spot, their hearts filled with excitement for the adventures that lay ahead. They had not only solved the mystery of the abandoned house but had also forged a new friendship that would last for years to come.
#
# And so, the Secret Society of Whiskers continued to thrive, their bond growing stronger with each passing night, proving that even the most unlikely of allies could come together for a common cause. In Willowbrook, the cats and raccoons became legends, their tales whispered among the townsfolk, who could never quite explain the strange happenings that seemed to protect their little town.
#
# JOKE:
# Why was the cat sitting on the computer?
#
# Because it wanted to keep an eye on the mouse!
#
# POEM:
# In sunlit corners, soft and sleek,
# With whispered purrs, they softly speak,
# A flick of tail, a playful leap,
# In dreams of mice, they gently creep.
#
# With emerald eyes that gleam like stars,
# They roam the night, like tiny czars,
# On velvet paws, they tread so light,
# Guardians of shadows, cloaked in night.
#
# A stretch, a yawn, a graceful pose,
# In every nook, their charm bestows,
# They curl like whispers, warm and round,
# In every heart, their love is found.
#
# From playful pounces to quiet grace,
# Each little quirk, a sweet embrace,
# With every meow, a tale unfolds,
# Of ancient lore and secrets told.
#
# Oh, creatures of mystery, soft and wise,
# With a flick of whiskers and knowing sighs,
# In your presence, the world feels right,
# Oh, beloved cats, our pure delight.
